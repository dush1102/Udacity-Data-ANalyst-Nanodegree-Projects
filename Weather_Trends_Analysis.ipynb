# %% [markdown]
# # Udacity Project 1: Weather Trends Analysis

# %% [markdown]
# ### Step2. Load the data

# %%
import pandas as pd
import numpy as np
#from datetime import datetime
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
#import pyEX as p

# %%
phoenix_data = pd.read_csv("./Phoenix_temperature.csv")
global_data = pd.read_csv("./Global_temperature.csv")
all_cities_data = pd.read_csv("./All_cities_temperature.csv")

# %%
phoenix_data.info() # No missing data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 4 columns):
# year        179 non-null int64
# city        179 non-null object
# country     179 non-null object
# avg_temp    179 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 5.7+ KB

# %% [markdown]
# ### Step3. Visualizations

# %%
window_size=10

# %%
phoenix_moving_avg = phoenix_data['avg_temp'].rolling(window=window_size).mean()
plt.figure(figsize=(12,5))
plt.plot(phoenix_data['year'], phoenix_data['avg_temp'], label='Phoenix avg. temp.', )
plt.plot(phoenix_data['year'], city_moving_avg, label='Phoenix moving average temp.')
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)") 
plt.title("Average Temperature Over Years")
plt.show();

# %%
chicago_data = all_cities_data.loc[all_cities_data['city'] == 'Chicago']

# %%
chicago_data.info() #missing values in avg_temp column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271 entries, 15107 to 15377
# Data columns (total 4 columns):
# year        271 non-null int64
# city        271 non-null object
# country     271 non-null object
# avg_temp    267 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 10.6+ KB

# %%
chicago_data.isna().sum() # 4 NaN values
# Out:
# year        0
# city        0
# country     0
# avg_temp    4
# dtype: int64

# %%
# Imputing null values with mean
chicago_data.avg_temp.fillna(chicago_data.avg_temp.mean(), inplace = True)
# Out:
# C:\Users\dushy\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
chicago_moving_avg = chicago_data['avg_temp'].rolling(window=window_size).mean()
plt.figure(figsize=(12,5))
plt.plot(chicago_data['year'], chicago_data['avg_temp'], label='Chicago avg. temp.', )
plt.plot(chicago_data['year'], chicago_moving_avg, label='Chicago moving average temp.')
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)") 
plt.title("Average Temperature Over Years")
plt.show()

# %%
oslo_data = all_cities_data.loc[all_cities_data['city'] == 'Oslo']

# %%
oslo_data.info() #missing values in avg_temp column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271 entries, 47832 to 48102
# Data columns (total 4 columns):
# year        271 non-null int64
# city        271 non-null object
# country     271 non-null object
# avg_temp    267 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 10.6+ KB

# %%
oslo_data.isna().sum() # 4 NaN values
# Out:
# year        0
# city        0
# country     0
# avg_temp    4
# dtype: int64

# %%
# Imputing null values with mean
oslo_data.avg_temp.fillna(oslo_data.avg_temp.mean(), inplace = True)
# Out:
# C:\Users\dushy\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
oslo_moving_avg = oslo_data['avg_temp'].rolling(window=window_size).mean()
plt.figure(figsize=(12,5))
plt.plot(oslo_data['year'], oslo_data['avg_temp'], label='Oslo avg. temp.', )
plt.plot(oslo_data['year'], oslo_moving_avg, label='Oslo moving average temp.')
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)") 
plt.title("Average Temperature Over Years")
plt.show();

# %%
global_moving_avg = global_data['avg_temp'].rolling(window=window_size).mean()
plt.figure(figsize=(12,5))
plt.plot(global_data['year'], global_moving_avg, label='Global moving avgerage temp.')
#sns.lmplot(x=global_data['year'], y=global_moving_avg, data=global_data, ci=None)
plt.plot(phoenix_data['year'], phoenix_moving_avg, label='Phoenix moving average temp.')
plt.plot(chicago_data['year'], chicago_moving_avg, label='Chicago moving average temp.')
plt.plot(oslo_data['year'], oslo_moving_avg, label='Oslo moving average temp.')
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)") 
plt.title("Cities vs Global Temperature")
plt.show();

# %%
plt.figure(figsize=(12,5))
plt.plot(global_data['year'], global_data['avg_temp'], label='Global avg. temp.', )
plt.plot(global_data['year'], global_moving_avg, label='Global moving average temp.')
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)") 
plt.title("Average Temperature Over Years")
plt.show();

# %%
chicago_data.shape
# Out:
# (271, 4)

# %%
global_data.shape
# Out:
# (266, 2)

# %%
plt.figure(figsize=(12,5))
plt.scatter(global_data['avg_temp'], chicago_data['avg_temp'].tail(266), alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('Global average temperature')
plt.ylabel('Chicago average temperature')
plt.show()

# %% [markdown]
# ### Step4. Observations

# %% [markdown]
# •	Phoenix’s and Chicago’s temperature is higher than global temperature, and Phoenix is a much hotter city as temperature difference is very high
# •	Oslo’s temperature is even lower than Global temperature, hence a very cold city.
# •	Difference between Global and Chicago’s temperature is approximately consistent over the years. Also, the sudden drop in temperature around the year 1820 is consistent in both global and Chicago.
# •	Overall trend of the global temperature is increasing (especially in the last 40 years)
# •	Except for the few outliers, there is a high correlation between Global and Chicago’s temperature
